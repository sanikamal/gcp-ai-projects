# %% [markdown]
# # Classifying Images with a NN and DNN Model
#
# ## Introduction
#
# In this notebook, you learn how to build a neural network to classify the tf-flowers dataset using a Deep Neural Network Model.
#
# ## Objectives
#
# * Define Helper Functions.
# * Train and evaluate a Neural Network (NN) model.
# * Train and evaluate a Deep Neural Network model.

# %%
# Import and print the installed version of TensorFlow
import tensorflow as tf
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
conda install graphviz
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Defining Helper Functions
# #### Reading and Preprocessing image data

# %%
# Helper functions
def training_plot(metrics, history):
  f, ax = plt.subplots(1, len(metrics), figsize=(5*len(metrics), 5))
  for idx, metric in enumerate(metrics):
    ax[idx].plot(history.history[metric], ls='dashed')
    ax[idx].set_xlabel("Epochs")
    ax[idx].set_ylabel(metric)
    ax[idx].plot(history.history['val_' + metric]);
    ax[idx].legend([metric, 'val_' + metric])

# Call model.predict() on a few images in the evaluation dataset
def plot_predictions(filename):
  f, ax = plt.subplots(3, 5, figsize=(25,15))
  dataset = (tf.data.TextLineDataset(filename).
      map(decode_csv))
  for idx, (img, label) in enumerate(dataset.take(15)):
    ax[idx//5, idx%5].imshow((img.numpy()));
    batch_image = tf.reshape(img, [1, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS])
    batch_pred = model.predict(batch_image)
    pred = batch_pred[0]
    label = CLASS_NAMES[label.numpy()]
    pred_label_index = tf.math.argmax(pred).numpy()
    pred_label = CLASS_NAMES[pred_label_index]
    prob = pred[pred_label_index]
    ax[idx//5, idx%5].set_title('{}: {} ({:.4f})'.format(label, pred_label, prob))

def show_trained_weights(model):
  # CLASS_NAMES is ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
  LAYER = 1 # Layer 0 flattens the image, layer=1 is the first dense layer
  WEIGHT_TYPE = 0 # 0 for weight, 1 for bias

  f, ax = plt.subplots(1, 5, figsize=(15,15))
  for flower in range(len(CLASS_NAMES)):
    weights = model.layers[LAYER].get_weights()[WEIGHT_TYPE][:, flower]
    min_wt = tf.math.reduce_min(weights).numpy()
    max_wt = tf.math.reduce_max(weights).numpy()
    flower_name = CLASS_NAMES[flower]
    print("Scaling weights for {} in {} to {}".format(
        flower_name, min_wt, max_wt))
    weights = (weights - min_wt)/(max_wt - min_wt)
    ax[flower].imshow(weights.reshape(IMG_HEIGHT, IMG_WIDTH, 3));
    ax[flower].set_title(flower_name);

# %%
# The import statement combines two operations; it searches for the named module, then it binds the results of that search
import matplotlib.pylab as plt
import numpy as np
import tensorflow as tf
IMG_HEIGHT = 224
IMG_WIDTH = 224
IMG_CHANNELS = 3

def read_and_decode(filename, reshape_dims):
  # Read the file
  img = tf.io.read_file(filename)
  # Convert the compressed string to a 3D uint8 tensor.
  img = tf.image.decode_jpeg(img, channels=IMG_CHANNELS)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # Resize the image to the desired size.
  return tf.image.resize(img, reshape_dims)

CLASS_NAMES = [item.numpy().decode("utf-8") for item in 
               tf.strings.regex_replace(
                 tf.io.gfile.glob("gs://practical-ml-vision-book/flowers_5_jpeg/flower_photos/*"),
                 "gs://practical-ml-vision-book/flowers_5_jpeg/flower_photos/", "")]
CLASS_NAMES = [item for item in CLASS_NAMES if item.find(".") == -1]
print("These are the available classes:", CLASS_NAMES)

# the label is the index into CLASS_NAMES array
def decode_csv(csv_row):
  record_defaults = ["path", "flower"]
  filename, label_string = tf.io.decode_csv(csv_row, record_defaults)
  img = read_and_decode(filename, [IMG_HEIGHT, IMG_WIDTH])
  label = tf.argmax(tf.math.equal(CLASS_NAMES, label_string))
  return img, label
# Out:
# These are the available classes: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# 2024-10-11 19:11:18.993498: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2024-10-11 19:11:18.993555: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-10-11 19:11:18.993606: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (instance-20241012-002411): /proc/driver/nvidia/version does not exist
# 2024-10-11 19:11:18.998070: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Train and evaluate a Neural Network (NN) model
#
# One way to get a more complex method is to interpose one or more Dense layers in between the input and output. The model now has three layers. A layer with trainable weights such as the one recently added, that is neither the input nor the output, is called a hidden layer.

# %% [markdown]
# In Keras, you introduce the activation function with tf.keras.activations.
#
# The Rectified Linear Unit (ReLU) is the most commonly used activation function for hidden layers – other commonly used activation functions include sigmoid, tanh, and elu.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt

fig, ax = plt.subplots(1, 3, figsize=(10,5))
x = np.arange(-10.0, 10.0, 0.1)
y = tf.keras.activations.sigmoid(x)
ax[0].plot(x, y);
ax[0].set_title("sigmoid")
y = tf.keras.activations.relu(x)
ax[1].plot(x, y);
ax[1].set_title("relu")
y = tf.keras.activations.elu(x)
ax[2].plot(x, y);
ax[2].set_title("elu");

# %%
model = tf.keras.Sequential([
   tf.keras.layers.Flatten(input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
   tf.keras.layers.Dense(128, activation='relu'),
   tf.keras.layers.Dense(len(CLASS_NAMES), activation='softmax')
])
model.summary()
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 150528)            0
#
#  dense (Dense)               (None, 128)               19267712
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 19,268,357
# Trainable params: 19,268,357
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = tf.keras.Sequential([
   tf.keras.layers.Flatten(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
   tf.keras.layers.Dense(len(CLASS_NAMES), activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 150528)            0
#
#  dense_2 (Dense)             (None, 5)                 752645
#
# =================================================================
# Total params: 752,645
# Trainable params: 752,645
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 32

train_dataset = (tf.data.TextLineDataset(
    "gs://practical-ml-vision-book/flowers_5_jpeg/flower_photos/train_set.csv").
    map(decode_csv)).batch(BATCH_SIZE)

eval_dataset = (tf.data.TextLineDataset(
    "gs://practical-ml-vision-book/flowers_5_jpeg/flower_photos/eval_set.csv").
    map(decode_csv)).batch(BATCH_SIZE)

# NN with one hidden layer
model = tf.keras.Sequential([
          tf.keras.layers.Flatten(input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)),
          tf.keras.layers.Dense(128, activation=tf.keras.activations.relu),
          tf.keras.layers.Dense(len(CLASS_NAMES), activation='softmax')
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])
history = model.fit(train_dataset, validation_data=eval_dataset, epochs=10)
# Out:
# Epoch 1/10
# 104/104 [==============================] - 83s 793ms/step - loss: 11.3605 - accuracy: 0.2888 - val_loss: 2.4869 - val_accuracy: 0.4027
# Epoch 2/10
# 104/104 [==============================] - 81s 781ms/step - loss: 2.2097 - accuracy: 0.4036 - val_loss: 3.2533 - val_accuracy: 0.4054
# Epoch 3/10
# 104/104 [==============================] - 83s 802ms/step - loss: 1.8236 - accuracy: 0.4385 - val_loss: 4.2714 - val_accuracy: 0.4162
# Epoch 4/10
# 104/104 [==============================] - 83s 800ms/step - loss: 1.9277 - accuracy: 0.4630 - val_loss: 1.7509 - val_accuracy: 0.3054
# Epoch 5/10
# 104/104 [==============================] - 83s 798ms/step - loss: 1.5195 - accuracy: 0.3830 - val_loss: 1.4660 - val_accuracy: 0.4054
# Epoch 6/10
# 104/104 [==============================] - 82s 788ms/step - loss: 1.5266 - accuracy: 0.3470 - val_loss: 1.5182 - val_accuracy: 0.4135
# Epoch 7/10
# 104/104 [==============================] - 83s 796ms/step - loss: 1.5171 - accuracy: 0.3436 - val_loss: 1.6287 - val_accuracy: 0.2865
# Epoch 8/10
# 104/104 [==============================] - 86s 826ms/step - loss: 1.5120 - accuracy: 0.3418 - val_loss: 1.5469 - val_accuracy: 0.3486
# Epoch 9/10
# 104/104 [==============================] - 86s 825ms/step - loss: 1.5234 - accuracy: 0.3330 - val_loss: 1.5724 - val_accuracy: 0.2757
# Epoch 10/10
# 104/104 [==============================] - 93s 891ms/step - loss: 1.5417 - accuracy: 0.3033 - val_loss: 1.5551 - val_accuracy: 0.3027

# %%
training_plot(['loss', 'accuracy'], history)

# %% [markdown]
# ## Training the neural network
#
# Training the neural network is similar to training the linear model. Compile the model passing in the optimizer, the loss, and the metrics. Then, call model.fit() passing in the datasets.

# %%
# parameterize to the values in the previous cell
def train_and_evaluate(batch_size = 32,
                       lrate = 0.001, # default in Adam constructor
                       l1 = 0,
                       l2 = 0,
                       num_hidden = 128):
  regularizer = tf.keras.regularizers.l1_l2(l1, l2)

  train_dataset = (tf.data.TextLineDataset(
      "gs://practical-ml-vision-book/flowers_5_jpeg/flower_photos/train_set.csv").
      map(decode_csv)).batch(batch_size)

  eval_dataset = (tf.data.TextLineDataset(
      "gs://practical-ml-vision-book/flowers_5_jpeg/flower_photos/eval_set.csv").
      map(decode_csv)).batch(32) # this doesn't matter

  # NN with one hidden layers
  model = tf.keras.Sequential([
              tf.keras.layers.Flatten(input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)),
              tf.keras.layers.Dense(num_hidden,
                                    kernel_regularizer=regularizer, 
                                    activation=tf.keras.activations.relu),
              tf.keras.layers.Dense(len(CLASS_NAMES), 
                                    kernel_regularizer=regularizer,
                                    activation='softmax')
  ])
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lrate),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                  metrics=['accuracy'])
    
  history = model.fit(train_dataset, validation_data=eval_dataset, epochs=10)
  training_plot(['loss', 'accuracy'], history)
  return model

# %% [markdown]
# First, train your model by using 128 hidden layers.

# %%
model = train_and_evaluate(batch_size=32, lrate=0.0001, l1=0, l2=0, num_hidden=128)
# Out:
# Epoch 1/10
# 104/104 [==============================] - 89s 844ms/step - loss: 2.4592 - accuracy: 0.3685 - val_loss: 1.9028 - val_accuracy: 0.3649
# Epoch 2/10
# 104/104 [==============================] - 95s 909ms/step - loss: 1.5454 - accuracy: 0.4391 - val_loss: 2.1433 - val_accuracy: 0.3405
# Epoch 3/10
# 104/104 [==============================] - 87s 839ms/step - loss: 1.4556 - accuracy: 0.4767 - val_loss: 1.6883 - val_accuracy: 0.4622
# Epoch 4/10
# 104/104 [==============================] - 86s 821ms/step - loss: 1.2255 - accuracy: 0.5282 - val_loss: 1.7968 - val_accuracy: 0.4486
# Epoch 5/10
# 104/104 [==============================] - 82s 784ms/step - loss: 1.2219 - accuracy: 0.5412 - val_loss: 2.3360 - val_accuracy: 0.4108
# Epoch 6/10
# 104/104 [==============================] - 81s 777ms/step - loss: 1.3173 - accuracy: 0.5394 - val_loss: 1.8174 - val_accuracy: 0.4324
# Epoch 7/10
# 104/104 [==============================] - 82s 788ms/step - loss: 1.1947 - accuracy: 0.5727 - val_loss: 1.6753 - val_accuracy: 0.4378
# Epoch 8/10
# 104/104 [==============================] - 82s 783ms/step - loss: 1.1840 - accuracy: 0.5658 - val_loss: 1.5118 - val_accuracy: 0.4703
# Epoch 9/10
# 104/104 [==============================] - 81s 779ms/step - loss: 1.0937 - accuracy: 0.5894 - val_loss: 1.8079 - val_accuracy: 0.4162
# Epoch 10/10
# 104/104 [==============================] - 83s 794ms/step - loss: 1.0537 - accuracy: 0.6091 - val_loss: 1.8925 - val_accuracy: 0.4027

# %% [markdown]
# You would normally expect that adding layers to a model will improve the ability of the model to fit the training data, and thus lower the loss. Notice that it is not always the case though.

# %%
model = train_and_evaluate(batch_size=32, lrate=0.0001, l1=0, l2=0, num_hidden=256)
# Out:
# Epoch 1/10
# 104/104 [==============================] - 93s 881ms/step - loss: 2.3964 - accuracy: 0.3585 - val_loss: 1.3012 - val_accuracy: 0.4459
# Epoch 2/10
# 104/104 [==============================] - 93s 895ms/step - loss: 1.3600 - accuracy: 0.4521 - val_loss: 1.5329 - val_accuracy: 0.4459
# Epoch 3/10
# 104/104 [==============================] - 92s 884ms/step - loss: 1.3028 - accuracy: 0.4755 - val_loss: 1.7074 - val_accuracy: 0.4297
# Epoch 4/10
# 104/104 [==============================] - 93s 895ms/step - loss: 1.2219 - accuracy: 0.5148 - val_loss: 1.5899 - val_accuracy: 0.4405
# Epoch 5/10
# 104/104 [==============================] - 93s 897ms/step - loss: 1.1573 - accuracy: 0.5409 - val_loss: 1.4794 - val_accuracy: 0.4595
# Epoch 6/10
# 104/104 [==============================] - 94s 896ms/step - loss: 1.1139 - accuracy: 0.5600 - val_loss: 1.2826 - val_accuracy: 0.4865
# Epoch 7/10
# 104/104 [==============================] - 93s 893ms/step - loss: 1.0738 - accuracy: 0.5833 - val_loss: 1.4007 - val_accuracy: 0.4541
# Epoch 8/10
# 104/104 [==============================] - 92s 880ms/step - loss: 1.0772 - accuracy: 0.5867 - val_loss: 1.4385 - val_accuracy: 0.4459
# Epoch 9/10
# 104/104 [==============================] - 93s 893ms/step - loss: 1.0611 - accuracy: 0.5952 - val_loss: 1.5022 - val_accuracy: 0.4541
# Epoch 10/10
# 104/104 [==============================] - 93s 891ms/step - loss: 0.9969 - accuracy: 0.6227 - val_loss: 1.5154 - val_accuracy: 0.4676

# %% [markdown]
# ## Train and evaluate a Deep Neural Network model
#
# Now train a DNN. You need to parameterize the number of layers, and the number of nodes in each layer.

# %%
# parameterize to the values in the previous cell
def train_and_evaluate(batch_size = 32,
                       lrate = 0.0001,
                       l1 = 0,
                       l2 = 0.001,
                       num_hidden = [64, 16]):
  regularizer = tf.keras.regularizers.l1_l2(l1, l2)

  train_dataset = (tf.data.TextLineDataset(
      "gs://practical-ml-vision-book/flowers_5_jpeg/flower_photos/train_set.csv").
      map(decode_csv)).batch(batch_size)

  eval_dataset = (tf.data.TextLineDataset(
      "gs://practical-ml-vision-book/flowers_5_jpeg/flower_photos/eval_set.csv").
      map(decode_csv)).batch(32) # this doesn't matter

  # NN with multiple hidden layers
  layers = [tf.keras.layers.Flatten(
      input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS),
      name='input_pixels')]
  layers = layers + [
      tf.keras.layers.Dense(nodes,
                            kernel_regularizer=regularizer, 
                            activation=tf.keras.activations.relu,
                            name='hidden_dense_{}'.format(hno))
          for hno, nodes in enumerate(num_hidden)
  ]
  layers = layers + [
      tf.keras.layers.Dense(len(CLASS_NAMES), 
                            kernel_regularizer=regularizer,
                            activation='softmax',
                            name='flower_prob')
  ]

  model = tf.keras.Sequential(layers, name='flower_classification')
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lrate),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(
                    from_logits=False),
                metrics=['accuracy'])
  print(model.summary())
  history = model.fit(train_dataset, validation_data=eval_dataset, epochs=10)
  training_plot(['loss', 'accuracy'], history)
  return model

# %%
model = train_and_evaluate(lrate=0.0001, l2=0.001, num_hidden = [64, 16])
# Out:
# Model: "flower_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_pixels (Flatten)      (None, 150528)            0
#
#  hidden_dense_0 (Dense)      (None, 64)                9633856
#
#  hidden_dense_1 (Dense)      (None, 16)                1040
#
#  flower_prob (Dense)         (None, 5)                 85
#
# =================================================================
# Total params: 9,634,981
# Trainable params: 9,634,981
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 104/104 [==============================] - 79s 750ms/step - loss: 1.8191 - accuracy: 0.3076 - val_loss: 1.6289 - val_accuracy: 0.3459
# Epoch 2/10
# 104/104 [==============================] - 77s 743ms/step - loss: 1.6953 - accuracy: 0.3127 - val_loss: 1.6296 - val_accuracy: 0.2946
# Epoch 3/10
# 104/104 [==============================] - 78s 746ms/step - loss: 1.6595 - accuracy: 0.3248 - val_loss: 1.6002 - val_accuracy: 0.3703
# Epoch 4/10
# 104/104 [==============================] - 78s 751ms/step - loss: 1.6448 - accuracy: 0.3458 - val_loss: 1.6116 - val_accuracy: 0.3730
# Epoch 5/10
# 104/104 [==============================] - 79s 757ms/step - loss: 1.5999 - accuracy: 0.3927 - val_loss: 1.5840 - val_accuracy: 0.3946
# Epoch 6/10
# 104/104 [==============================] - 77s 740ms/step - loss: 1.6039 - accuracy: 0.3621 - val_loss: 1.5184 - val_accuracy: 0.3865
# Epoch 7/10
# 104/104 [==============================] - 78s 753ms/step - loss: 1.5554 - accuracy: 0.4073 - val_loss: 1.5700 - val_accuracy: 0.3865
# Epoch 8/10
# 104/104 [==============================] - 79s 757ms/step - loss: 1.5409 - accuracy: 0.4082 - val_loss: 1.5767 - val_accuracy: 0.3676
# Epoch 9/10
# 104/104 [==============================] - 77s 737ms/step - loss: 1.5134 - accuracy: 0.4209 - val_loss: 1.5430 - val_accuracy: 0.3595
# Epoch 10/10
# 104/104 [==============================] - 77s 742ms/step - loss: 1.5045 - accuracy: 0.4064 - val_loss: 1.5454 - val_accuracy: 0.3595
